# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
res=requests.get('https://www.amazon.in/s?k=multivitamin+best&crid=ZE80G2W16TD2&sprefix=multivitamin+best+%2Caps%2C456&ref=nb_sb_noss_2',headers=headers).text
res
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(
# ...

# %%
soup=BeautifulSoup(res,'lxml')
fn=str(soup)

# %%
hold=soup.find_all('div','sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 AdHolder sg-col s-widget-spacing-small sg-col-4-of-20')
print(len(hold))
# Out:
# 12

# %%
box=soup.find_all('div','sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20')
len(soup.find_all('div','sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20'))
# Out:
# 48

# %%
soup.find_all('span','a-size-base-plus a-color-base a-text-normal')
# Out:
# [<span class="a-size-base-plus a-color-base a-text-normal">TrueBasics Multivit Daily, Multivitamin For Men and Women, with Zinc, Vitamin C, D, B12 and Multiminerals, Immunity and Antioxidant Blend, Clinically Researched Ingredients, 60 Multivitamin Tablets</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">Swisse Men’s Multivitamin - 60 Tabs (Australia's No.1 Multivitamin Brand) Increases Immunity, Energy, Stamina &amp; Vitality Production With 36 Herbs, Vitamins &amp; Minerals</span>,
#  <span class="a-size-base-plus a-color-base a-text-normal">TrueBasics Multivit Men, Multivitamin For Men, With Zinc, Vitamin C, Vitamin D3 and Multiminerals, Antioxidant-Rich, Stress Buster Blend, Clinically Researched Ingredients, 30 Multivitamin Tablets</span>,
# ...

# %%
for it in hold:
    simp=str(it.find('div','a-row a-size-base a-color-base'))
    if simp.find("off)</")!= -1:
        print("YES !!!! PUSSY")
#     print(it.find('div','a-row a-size-base a-color-base'))
#     print("\n\n\n\n\n\n\n\n")
# prin
# Out:
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY
# YES !!!! PUSSY

# %%
new =soup.find('div','a-row a-size-base a-color-base')
# print(new)
for it in soup.find_all('div','a-row a-size-base a-color-base'):
    print(it.find('span'))
# Out:
# <span class="a-price" data-a-color="base" data-a-size="xl"><span class="a-offscreen">₹699</span><span aria-hidden="true"><span class="a-price-symbol">₹</span><span class="a-price-whole">699</span></span></span>
# <span class="a-price" data-a-color="base" data-a-size="xl"><span class="a-offscreen">₹1,619</span><span aria-hidden="true"><span class="a-price-symbol">₹</span><span class="a-price-whole">1,619</span></span></span>
# <span class="a-price" data-a-color="base" data-a-size="xl"><span class="a-offscreen">₹565</span><span aria-hidden="true"><span class="a-price-symbol">₹</span><span class="a-price-whole">565</span></span></span>
# <span class="a-price" data-a-color="base" data-a-size="xl"><span class="a-offscreen">₹1,099</span><span aria-hidden="true"><span class="a-price-symbol">₹</span><span class="a-price-whole">1,099</span></span></span>
# ...

# %%
# for it in

# %%
# product=('span','a-size-base-plus a-color-base a-text-normal')
# rating=('span','a-size-base s-underline-text')
# star=('span','a-icon-alt')
# price=('span','a-price-whole')
# discount=('span','a-letter-space')
# mrp=('span','a-offscreen')
# product_link=('a','a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal')
# product_name=('img','s-image')

# %%
product_name=[]
quantity=[]
avg_star=[]
rating=[]
mrp=[]
discount=[]
price=[]
product_link=[]
product_image_link=[]
website=[]
fn=str(soup)
# mark1='{"image":"'
# mark2 ='","name":"'
# regexPattern = mark1 + '(.+?)' + mark2
# str_found = re.search(regexPattern, fn).group(1)

for i in box:
    
        if i.find('span','a-size-base-plus a-color-base a-text-normal') != None:
            product_name.append(i.find('span','a-size-base-plus a-color-base a-text-normal').text)
            pro_name=i.find('span','a-size-base-plus a-color-base a-text-normal').text
#             print(pro_name)
        else:
            product_name.append("NA")
#         if i.find("div","style__pack-size___2JQG7") !=None:
#             quantity.append(i.find("div","style__pack-size___2JQG7").text)
#         else :
#             quantity.append("NA")
        if i.find('span','a-icon-alt') !=None:
            temp=str(i.find('span','a-icon-alt').text)
            temp_index=temp.find("o")
            avg_star.append(temp[:temp_index-1])
        else:
            avg_star.append("NA")
        if i.find('span','a-size-base s-underline-text')!= None:
            brac=i.find('span','a-size-base s-underline-text').text
            rating.append(brac[1:-1]+" ratings")
        else :
            rating.append("NA")
        if i.find('span','a-price a-text-price') != None:
            simp=i.find('span','a-price a-text-price')
            mrp.append(simp.find('span','a-offscreen').text)
        else:
            mrp.append("NA")
        if i.find('div','a-row a-size-base a-color-base') !=None:
            new=str(i.find('div','a-row a-size-base a-color-base'))
            index=new.find("off)</")
            if(index!=-1):   
                if new[index-4]=='(':
                    discount.append(new[index-3:index+3])
                else:
                    discount.append(new[index-4:index+3])
                
            else :
                discount.append("NA")
        else :
            discount.append("NA")
        if i.find('span','a-price-whole') !=None:
            price.append(i.find('span','a-price-whole').text)
        else:
            price.append("NA")
        if i.find('a','a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal')!= None:
            product_link.append("https://www.amazon.in"+i.find('a','a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal').get('href'))
            pro_link=i.find('a','a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal').get('href')
        else :
            product_link.append("NA")
        if i.find("img")!=None:
            product_image_link.append(i.find("img")["src"])
        else:
            product_image_link.append("NA")
            
        website.append("Amazon")
            
            
#         mark1='\\",\\"image\\":\\"'
#         front=pro_link+mark1

#         fidx=fn.find(front)
#         new_str=fn[fidx+len(front):]
#         s_idx=new_str.find("\\")

#         first_idx=fidx+len(front)
#         product_image_link.append(fn[first_idx:first_idx+s_idx])
#         print(fn[first_idx:first_idx+s_idx])

        
print(len(product_name))
print(len(avg_star))
print(len(rating))
print(len(mrp))
print(len(product_link))
print(len(product_image_link))
print(rating)
print(avg_star)
# Out:
# 48
# 48
# 48
# 48
# 48
# 48
# ['4,136 ratings', '11,087 ratings', '620 ratings', '4,331 ratings', '11,871 ratings', '545 ratings', '653 ratings', '286 ratings', '166 ratings', '152 ratings', '5,274 ratings', '3,772 ratings', '1,041 ratings', '725 ratings', '5,419 ratings', '316 ratings', '608 ratings', '131 ratings', '128 ratings', '35 ratings', '1,457 ratings', '1,075 ratings', '190 ratings', '4,454 ratings', '1,017 ratings', '115 ratings', '782 ratings', '1,847 ratings', '3,458 ratings', '1,821 ratings', '2,430 ratings', '1,872 ratings', '88 ratings', '3,860 ratings', '184 ratings', '542 ratings', '2,520 ratings', '231 ratings', '87 ratings', '397 ratings', '831 ratings', '237 ratings', '17 ratings', '745 ratings', '29 ratings', '1,806 ratings', '133 ratings', '172 ratings']
# ...

# %%
df=pd.DataFrame({"Product Name":product_name,"Price":price,"Discount":discount,"MRP": mrp,"Rating":rating,"Average Star":avg_star,"Product_Link":product_link,"Product Image Link":product_image_link,"Website":website})

# %%
print((df))
# Out:
#                                          Product Name  Price Discount     MRP  \
# 0   Carbamide Forte Multivitamin Tablets for Men &...    569  33% off    ₹850
# 1   HealthKart HK Vitals Multivitamin for Men and ...    425  35% off    ₹650
# 2   Carbamide Forte Plant Based Multivitamin Table...    474  30% off    ₹675
# 3   HealthKart HK Vitals Multivitamin and Fish Oil...    719  47% off  ₹1,349
# 4   MuscleBlaze MB-Vite Daily Multivitamin with 51...    499  29% off    ₹699
# 5   Zingavita Multivitamin Tablets with Probiotics...    299  40% off    ₹499
# 6   Carbamide Forte Multivitamin Gummies for Women...    474  30% off    ₹675
# 7   Cipla Maxirich Daily Multivitamin (60 Softgels...    422  41% off    ₹714
# 8   Man Matters Multivitamin gummies For Men | vit...    499  17% off    ₹599
# 9   OZiva Daily Women’s Multi, 60 Tablets | Multiv...    427  14% off    ₹499
# 10  Revital H Multivitamin For Men With Natural Gi...    467  15% off    ₹550
# ...

# %%
df.to_csv("amazon_offer_list.csv")

# %%
import requests as rq
import os
import pathlib


def save_image(folder: str, name: str, url: str):
    # Get the data from the url
    image_source = rq.get(url)

    # If there's a suffix, we will grab that
    suffix = pathlib.Path(url).suffix

    # Check if the suffix is one of the following
    if suffix not in ['.jpg', '.jpeg', '.png', '.gif']:
        # Default to .png
        output = name + '.png'
    else:
        output = name + suffix

    # Check first if folder exists, else create a new one
    if not os.path.exists(folder):
        os.makedirs(folder)

    # Create our output in the specified folder (wb = write bytes)
    with open(f'{folder}{output}', 'wb') as file:
        file.write(image_source.content)
        print(f'Successfully downloaded: {output}')


        
        
for it in range(len(product_image_link)):
    image_url = product_image_link[it]
    output_name = product_name[it]

    save_image('amazon_images/', output_name, image_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 36
#      33 image_url = product_image_link[it]
#      34 output_name = product_name[it]
# ---> 36 save_image('amazon_images/', output_name, image_url)
#
# Cell In[17], line 25, in save_image(folder, name, url)
#      22     os.makedirs(folder)
#      24 # Create our output in the specified folder (wb = write bytes)
# ---> 25 with open(f'{folder}{output}', 'wb') as file:
#      26     file.write(image_source.content)
#      27     print(f'Successfully downloaded: {output}')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
# ...
